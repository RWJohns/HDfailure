# %%
import pandas as pd
import seaborn as sns

# %%
df_in = pd.read_csv("Data/model_2016_ST4000DM000.csv")

# %%
df=df_in

# %%
df.count()
# Out:
# date                    1076071
# serial_number           1076071
# model                   1076071
# capacity_bytes          1076071
# failure                 1076071
# smart_1_normalized      1076069
# smart_1_raw             1076069
# smart_2_normalized            0
# smart_2_raw                   0
# smart_3_normalized      1076069
# smart_3_raw             1076069
# smart_4_normalized      1076069
# smart_4_raw             1076069
# smart_5_normalized      1076069
# smart_5_raw             1076069
# smart_7_normalized      1076069
# smart_7_raw             1076069
# smart_8_normalized            0
# smart_8_raw                   0
# smart_9_normalized      1076069
# smart_9_raw             1076069
# smart_10_normalized     1076069
# smart_10_raw            1076069
# smart_11_normalized           0
# smart_11_raw                  0
# smart_12_normalized     1076069
# smart_12_raw            1076069
# smart_13_normalized           0
# smart_13_raw                  0
# ...

# %%
for column in df.columns:
    if df[column].count() == 0:
        del df[column]

# %%
del df['smart_1_normalized']
del df['smart_1_raw']

del df['smart_3_normalized']
del df['smart_3_raw']

del df['smart_4_normalized']
del df['smart_4_raw']

del df['smart_5_raw']
del df['smart_5_normalized']

del df['smart_7_raw']
del df['smart_7_normalized']

del df['smart_9_normalized']
del df['smart_9_raw']

del df['smart_10_normalized']
del df['smart_10_raw']

del df['smart_12_raw']
del df['smart_12_normalized']

del df['smart_183_raw']
del df['smart_183_normalized']

del df['smart_184_raw']
del df['smart_184_normalized']

del df['smart_187_normalized']

del df['smart_188_normalized']

del df['smart_189_normalized']

del df['smart_190_normalized']
del df['smart_190_raw']

del df['smart_191_normalized']
del df['smart_191_raw']

del df['smart_192_normalized']

del df['smart_193_raw']
del df['smart_193_normalized']

del df['smart_194_raw']
del df['smart_194_normalized']

del df['smart_197_normalized']

#you don't need both 197 and 198 but will leave in for now to weight this one because it is strong
del df['smart_198_normalized']

del df['smart_199_normalized']
del df['smart_199_raw']

del df['smart_240_normalized']
del df['smart_240_raw']

del df['smart_241_normalized']
del df['smart_241_raw']

del df['smart_242_normalized']

# %%
del df['smart_1_normalized']
del df['smart_1_raw']

del df['smart_3_normalized']
del df['smart_3_raw']

del df['smart_4_normalized']
del df['smart_4_raw']

del df['smart_5_raw']
del df['smart_5_normalized']

del df['smart_7_raw']
del df['smart_7_normalized']

del df['smart_9_normalized']
del df['smart_9_raw']

del df['smart_10_normalized']
del df['smart_10_raw']

del df['smart_12_raw']
del df['smart_12_normalized']

del df['smart_183_raw']
del df['smart_183_normalized']

del df['smart_184_raw']
del df['smart_184_normalized']

del df['smart_187_raw']

del df['smart_188_raw']

del df['smart_189_raw']

del df['smart_190_normalized']
del df['smart_190_raw']

del df['smart_191_normalized']
del df['smart_191_raw']

del df['smart_192_raw']

del df['smart_193_raw']
del df['smart_193_normalized']

del df['smart_194_raw']
del df['smart_194_normalized']

del df['smart_197_raw']

#you don't need both 197 and 198 but will leave in for now to weight this one because it is strong
del df['smart_198_raw']

del df['smart_199_normalized']
del df['smart_199_raw']

del df['smart_240_normalized']
del df['smart_240_raw']

del df['smart_241_normalized']
del df['smart_241_raw']

del df['smart_242_raw']

# %%
df2=df

# %%
df2.dropna(inplace=True)

# %%
df2.count()
# Out:
# date                    1076069
# serial_number           1076069
# model                   1076069
# capacity_bytes          1076069
# failure                 1076069
# smart_187_normalized    1076069
# smart_188_normalized    1076069
# smart_189_normalized    1076069
# smart_192_normalized    1076069
# smart_197_normalized    1076069
# smart_198_normalized    1076069
# smart_242_normalized    1076069
# dtype: int64

# %%
df_pair=df2

# %%
df2.to_pickle("2016_pickle.pkl")

# %%
df2.to_pickle("2016_pickle_norm.pkl")

# %%
use_df = pd.read_pickle("2016_pickle.pkl")

# %%
del df_pair['date']
del df_pair['serial_number']
del df_pair['model']
del df_pair['capacity_bytes']

# %%
df_pair.dropna(inplace=True)
df_pair.count()
# Out:
# failure                 1076069
# smart_4_normalized      1076069
# smart_5_normalized      1076069
# smart_7_normalized      1076069
# smart_12_normalized     1076069
# smart_183_normalized    1076069
# smart_184_normalized    1076069
# smart_187_normalized    1076069
# smart_188_raw           1076069
# smart_189_normalized    1076069
# smart_192_raw           1076069
# smart_193_raw           1076069
# smart_194_normalized    1076069
# smart_197_normalized    1076069
# smart_198_normalized    1076069
# smart_199_raw           1076069
# smart_241_raw           1076069
# smart_242_raw           1076069
# dtype: int64

# %%
use_df.head(20)
# Out:
#           date serial_number        model  capacity_bytes  failure  \
# 0   2016-01-01      W300K1XB  ST4000DM000   4000787030016        0
# 1   2016-01-01      Z300H1WJ  ST4000DM000   4000787030016        0
# 2   2016-01-01      Z304JL7B  ST4000DM000   4000787030016        0
# 3   2016-01-01      Z302BVHP  ST4000DM000   4000787030016        0
# 4   2016-01-01      S300Z5BS  ST4000DM000   4000787030016        0
# 5   2016-01-01      W300D5SS  ST4000DM000   4000787030016        0
# 6   2016-01-01      Z300ZT4N  ST4000DM000   4000787030016        0
# 7   2016-01-01      Z303R53M  ST4000DM000   4000787030016        0
# 8   2016-01-01      Z3014PCP  ST4000DM000   4000787030016        0
# 9   2016-01-01      Z300S25Y  ST4000DM000   4000787030016        0
# 10  2016-01-01      W300V80Z  ST4000DM000   4000787030016        0
# 11  2016-01-01      Z302A13D  ST4000DM000   4000787030016        1
# 12  2016-01-01      Z300K8F7  ST4000DM000   4000787030016        0
# ...

# %%
pp = sns.pairplot(data=df,
                  y_vars=['failure'],
                  x_vars=['smart_1_normalized','smart_3_normalized','smart_4_normalized','smart_5_normalized'])

# %%
pp = sns.pairplot(data=df,
                  y_vars=['failure'],
                  x_vars=['smart_7_normalized','smart_9_normalized','smart_10_normalized','smart_12_normalized'])

# %%
pp = sns.pairplot(data=df,
                  y_vars=['failure'],
                  x_vars=['smart_183_normalized','smart_184_normalized','smart_187_normalized','smart_188_normalized'])

# %%
pp = sns.pairplot(data=df,
                  y_vars=['failure'],
                  x_vars=['smart_189_normalized','smart_190_normalized','smart_191_normalized','smart_192_normalized'])

# %%
pp = sns.pairplot(data=df,
                  y_vars=['failure'],
                  x_vars=['smart_193_normalized','smart_194_normalized','smart_197_normalized','smart_198_normalized'])

# %%
pp = sns.pairplot(data=df,
                  y_vars=['failure'],
                  x_vars=['smart_199_normalized','smart_240_normalized','smart_241_normalized','smart_242_normalized'])

# %%
sns.stripplot(x=df['failure'], y=df['capacity_bytes']);

# %%
sns.stripplot(x=df['failure'], y=df['smart_197_raw']);

# %%
g=sns.regplot(x=df['failure'], y=df['smart_4_normalized']);

# %%
g=sns.regplot(x=df['failure'], y=df['smart_5_normalized']);

# %%
g=sns.regplot(x=df['failure'], y=df['smart_12_normalized']);

# %%
g=sns.regplot(x=df['failure'], y=df['smart_184_normalized']);

# %%
g=sns.regplot(x=df['failure'], y=df['smart_242_raw']);

# %%
b=sns.regplot(x=df['failure'], y=df['smart_199_raw']);

# %%
sns.stripplot(x=df['failure'], y=df['smart_183_normalized']);

# %%
sns.regplot(x=df['smart_198_raw'], y=df['smart_197_raw'])

# %%
sns.pairplot(df_pair)

# %%
df.describe()
# Out:
#        capacity_bytes       failure  smart_4_normalized  smart_5_normalized  \
# count    1.076071e+06  1.076071e+06        1.076069e+06        1.076069e+06
# mean     4.000780e+12  5.827404e-02        9.999989e+01        9.999636e+01
# std      5.454309e+09  2.342610e-01        1.060348e-02        1.554496e-01
# min     -1.000000e+00  0.000000e+00        9.900000e+01        7.800000e+01
# 25%      4.000787e+12  0.000000e+00        1.000000e+02        1.000000e+02
# 50%      4.000787e+12  0.000000e+00        1.000000e+02        1.000000e+02
# 75%      4.000787e+12  0.000000e+00        1.000000e+02        1.000000e+02
# max      4.000787e+12  1.000000e+00        1.000000e+02        1.000000e+02
#
#        smart_7_normalized  smart_12_normalized  smart_183_normalized  \
# count        1.076069e+06         1.076069e+06          1.076069e+06
# mean         8.430111e+01         9.999820e+01          9.975370e+01
# std          3.443890e+00         1.696557e-01          2.874528e+00
# ...

# %%
df.count()
# Out:
# date                    1076071
# serial_number           1076071
# model                   1076071
# capacity_bytes          1076071
# failure                 1076071
# smart_4_normalized      1076069
# smart_5_normalized      1076069
# smart_7_normalized      1076069
# smart_12_normalized     1076069
# smart_183_normalized    1076069
# smart_184_normalized    1076069
# smart_187_normalized    1076069
# smart_188_raw           1076069
# smart_189_normalized    1076069
# smart_192_raw           1076069
# smart_193_raw           1076069
# smart_194_normalized    1076069
# smart_197_normalized    1076069
# smart_198_normalized    1076069
# smart_199_raw           1076069
# smart_241_raw           1076069
# smart_242_raw           1076069
# dtype: int64

# %%
df = df.smart_2_normalized.drop
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-9c8ffe2b0c39> in <module>
# ----> 1 df = df.smart_2_normalized.drop
#
# AttributeError: 'function' object has no attribute 'smart_2_normalized'

# %%
df.head()
# Out:
#          date serial_number        model  capacity_bytes  failure  \
# 0  2016-01-01      W300K1XB  ST4000DM000   4000787030016        0
# 1  2016-01-01      Z300H1WJ  ST4000DM000   4000787030016        0
# 2  2016-01-01      Z304JL7B  ST4000DM000   4000787030016        0
# 3  2016-01-01      Z302BVHP  ST4000DM000   4000787030016        0
# 4  2016-01-01      S300Z5BS  ST4000DM000   4000787030016        0
#
#    smart_4_normalized  smart_5_normalized  smart_7_normalized  \
# 0               100.0               100.0                84.0
# 1               100.0               100.0                89.0
# 2               100.0               100.0                80.0
# 3               100.0               100.0                81.0
# 4               100.0               100.0                84.0
#
#    smart_12_normalized  smart_183_normalized  ...  smart_188_raw  \
# 0                100.0                  99.0  ...            0.0
# ...
